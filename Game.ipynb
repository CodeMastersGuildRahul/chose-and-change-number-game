# %%
from IPython.core.display_functions import clear_output

print("hello")
# Out:
# hello

# %%
from IPython.display import  clear_output

# %%
game_list = [0,1,2]

# %%
def display_game(game_list):
    print("hear is the current list")
    print(game_list)

# %%
display_game(game_list)
# Out:
# hear is the current list
# [0, 1, 2]

# %%
def position_choice():
    choice = 'wrong'

    while choice not in ['0','1','2']:
        choice = input("Pick a position to replace(0,1,2): ")

        if choice not in['0','1','2']:

            print("sorry, but you did not choose a valid position(0,1,2)")

    return int(choice)

# %%
def replacement_choice(game_list,position):

    user_placement = input("Type a string to place at the position")

    game_list[position] = user_placement

    return game_list

# %%
replacement_choice(game_list,1)
# Out:
# [0, 'test', 2]

# %%
def gameon_choice():

    choice = 'Wrong'

    while choice not in ['Y','N']:
        choice = input("Would you like to keep playing?(Y/N): ")

        if choice not in['Y','N']:

             print("sorry, I didn't understand. Please type Y or N")

    if choice == "Y":
           return True
    else:
           return False
    return None

# %%
gameon_choice()
# Out:
# True

# %%
game_on = True
game_list = [0,1,2]

while game_on:


    display_game(game_list)

    position = position_choice()

    game_list= replacement_choice(game_list,position)


    display_game(game_list)

    game_on = gameon_choice()
# Out:
# hear is the current list
# [0, 1, 2]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 9
#       4 while game_on:
#       7     display_game(game_list)
# ----> 9     position = position_choice()
#      11     game_list= replacement_choice(game_list,position)
#      14     display_game(game_list)
#
# Cell In[36], line 5, in position_choice()
#       2 choice = 'wrong'
#       4 while choice not in ['0','1','2']:
# ----> 5     choice = input("Pick a position to replace(0,1,2): ")
#       7     if choice not in['0','1','2']:
#       9         print("sorry, but you did not choose a valid position(0,1,2)")
#
# File C:\Program Files\Python314\Lib\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File C:\Program Files\Python314\Lib\site-packages\ipykernel\kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
